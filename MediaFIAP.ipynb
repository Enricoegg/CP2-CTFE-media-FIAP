# %% [markdown]
# <a href="https://colab.research.google.com/github/Enricoegg/CP2-CTFE-media-FIAP/blob/main/MediaFIAP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Cálculo da média FIAP**
